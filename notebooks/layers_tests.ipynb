# %%
from pathlib import Path
import os
import sys

project_root = Path.cwd().resolve()
if project_root.name == "notebooks":
    project_root = project_root.parent

project_root_str = str(project_root)
if project_root_str not in sys.path:
    sys.path.insert(0, project_root_str)

os.chdir(project_root_str)

#####Above code is AI generated. i dont know how it works but it does. :)

# %%
from tests.layer_b.test_layer_b import test_layer_b

test_layer_b()

# %%
from tests.layer_c.test_layer_c import test_layer_c

test_layer_c()

# %%
from tests.layer_d.test_layer_d import test_layer_d

test_layer_d()
# Out:
# Loaded trained thresholds: low=0.2000, high=0.8000
# Loading Layer D model from: /home/iaa1/Documents/barrikade/core/layer_d/outputs/model
# Loading weights: 100%|██████████| 174/174 [00:00<00:00, 22878.02it/s]
# Classifying 0/9386...
# Classifying 500/9386...
# Classifying 1000/9386...
# Classifying 1500/9386...
# Classifying 2000/9386...
# Classifying 2500/9386...
# Classifying 3000/9386...
# Classifying 3500/9386...
# Classifying 4000/9386...
# Classifying 4500/9386...
# Classifying 5000/9386...
# Classifying 5500/9386...
# Classifying 6000/9386...
# Classifying 6500/9386...
# Classifying 7000/9386...
# Classifying 7500/9386...
# Classifying 8000/9386...
# Classifying 8500/9386...
# Classifying 9000/9386...
#
# ...
# CONFUSION MATRIX
# ...
# Ground Truth    |      Allow |       Flag |      Block |      Total
# --------------------------------------------------------------------
# SAFE            |       3343 |       1191 |        143 |       4677
# ...

# %%
from tests.layer_e.test_layer_e import test_layer_e

test_layer_e()

# %%
from tests.test_pipeline_full_pass import run_full_pipeline_pass

run_full_pipeline_pass()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tests.layer_b.test_layer_b import test_layer_b
#       3 test_layer_b()
#
# ModuleNotFoundError: No module named 'tests'
